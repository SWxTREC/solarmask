# %%
from flares.data import get_dates
from flares.ARDataSet import ARDataSet
import numpy as np

if __name__ == '__main__':
    root = "/srv/data/thli2739"
    dates = get_dates(7115, root)
    

    dates = get_dates(7115, root, sort = True)
    ar = ARDataSet(7115, root, dates[23:], verbose = True, frame_dir = "./frames")
# Out:
# Working on 7115, 2017-08-29 10:00:00
# ...
# 0.002515077590942383 Bz_moments
# 0.0005848407745361328 Bz_tot
# 0.0004620552062988281 Bz_totabs
# 0.0035638809204101562 Bh_moments
# 0.0019979476928710938 gamma_moments
# 0.0046520233154296875 GradB_moments
# 0.0020601749420166016 GradBz_moments
# 0.0024094581604003906 GradBh_moments
# 0.0035390853881835938 J_moments
# 0.00030231475830078125 itot
# 0.0002837181091308594 itotabs
# 0.001199960708618164 itot_polarity
# 0.003688812255859375 Jh_moments
# 0.00040531158447265625 ihtot
# 0.0005528926849365234 ihtotabs
# 0.0013744831085205078 twist_moments
# 0.0017137527465820312 hc_moments
# 0.00029850006103515625 hctot
# 0.0002880096435546875 hctotabs
# 0.029714345932006836 shear_moments
# 0.0018298625946044922 rho_moments
# 0.0002932548522949219 totrho
# 0.0069904327392578125 entropy
# ...
# 0.0008478164672851562 Bz_moments
# 0.0003917217254638672 Bz_tot
# 0.00036215782165527344 Bz_totabs
# 0.0005869865417480469 Bh_moments
# ...
